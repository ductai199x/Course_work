# %% [markdown]
# # Homework 3

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import IPython.display as ipd
from scipy import signal

# %matplotlib inline

# %% [markdown]
# ## Proakis 5.3a:

# %%
numH = [1, 0]
denH = [1, -0.5]
#################

# compute the impulse response
systemH = signal.dlti(numH, denH)

# %%
w = np.linspace(-np.pi,np.pi,10000)
w, H = signal.dfreqresp(systemH, w)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 5.3b

# %%
n = np.linspace(-100,100,10000)
x_n = np.cos(3*np.pi*n/10)

X_k = np.fft.fft(x_n,)

Y_k = X_k*H

plt.figure(figsize = (15,5))
plt.stem(w, np.abs(Y_k));

plt.figure(figsize = (15,5))
plt.stem(w, np.angle(Y_k));

# %%
# Out:
# 10000

# %% [markdown]
# ## Proakis 5.4b

# %%
numX = [0.5, -1]
denX = [1, 0]
#################

# compute the impulse response
systemX = signal.dlti(numX, denX)

w = np.linspace(0,np.pi,10000)
w, H = signal.dfreqresp(systemX, w)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 5.4c

# %%
j = np.complex(0,1)

w = np.linspace(0,np.pi,10000)
H = np.sin(w)*np.exp(j*np.pi/2)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 5.4i

# %%
w = np.linspace(0,np.pi,10000)
H = 2*np.exp(-j*w) - np.exp(-j*2*w)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %%
w = np.linspace(0,np.pi,10000)
H = np.cos(w)*np.cos(w/2)*np.exp(-j*3*w/2)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %%
w = np.linspace(0,np.pi,10000)
H = np.cos(w/2)*np.cos(w/2)*np.cos(w/2)*np.exp(-j*3*w/2)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 7.17

# %%
x_n = [1,1,1,1,1,1,0,0]
N = 8

X_k = np.fft.fft(x_n, n=N)

k = np.linspace(0,N,N)
                 
print(k)

plt.figure(figsize = (15,5))
plt.stem(k, np.abs(X_k));

plt.figure(figsize = (15,5))
plt.stem(k, np.angle(X_k));
