# %%
import sys, os
import pickle
import time
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import itertools
import pandas as pd
import seaborn as sn

# %%
conf_mat = np.array([[1462,    1,    2,    0,    2,    3,    7,    0,    3,    1],
       [   0, 1666,    7,    0,    3,    1,    2,    0,    3,    3],
       [   6,    6, 1430,   11,    3,    4,    4,   14,   11,    1],
       [   7,   10,   13, 1442,    3,   23,    3,   12,   12,    8],
       [   1,    5,    4,    2, 1370,    1,    8,    5,    6,   58],
       [   5,    3,    2,   33,    3, 1266,   21,    2,   11,    9],
       [   6,    7,    0,    0,    2,   11, 1451,    0,    3,    0],
       [   2,   16,    9,    1,   12,    0,    0, 1505,    6,   15],
       [   6,   25,    5,   21,   11,   15,    9,    7, 1350,   14],
       [   5,    4,    1,    8,   37,    3,    2,   29,    8, 1390]])

# %%
df_cm = pd.DataFrame(conf_mat, range(10), range(10))
df_cm = df_cm.div(df_cm.sum(axis=1), axis=0).round(2)
plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()

# %%
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.987171  0.000675  0.001350  0.000000  0.001350  0.002026  0.004727
# 1  0.000000  0.988724  0.004154  0.000000  0.001780  0.000593  0.001187
# 2  0.004027  0.004027  0.959732  0.007383  0.002013  0.002685  0.002685
# 3  0.004566  0.006523  0.008480  0.940639  0.001957  0.015003  0.001957
# 4  0.000685  0.003425  0.002740  0.001370  0.938356  0.000685  0.005479
# 5  0.003690  0.002214  0.001476  0.024354  0.002214  0.934317  0.015498
# 6  0.004054  0.004730  0.000000  0.000000  0.001351  0.007432  0.980405
# 7  0.001277  0.010217  0.005747  0.000639  0.007663  0.000000  0.000000
# 8  0.004101  0.017088  0.003418  0.014354  0.007519  0.010253  0.006152
# 9  0.003362  0.002690  0.000672  0.005380  0.024882  0.002017  0.001345
#
#           7         8         9
# 0  0.000000  0.002026  0.000675
# 1  0.000000  0.001780  0.001780
# 2  0.009396  0.007383  0.000671
# 3  0.007828  0.007828  0.005219
# 4  0.003425  0.004110  0.039726
# 5  0.001476  0.008118  0.006642
# 6  0.000000  0.002027  0.000000
# 7  0.961047  0.003831  0.009579
# 8  0.004785  0.922761  0.009569
# 9  0.019502  0.005380  0.934768
