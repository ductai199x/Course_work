# %% [markdown]
# # Homework 3

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import IPython.display as ipd
from scipy import signal

# %matplotlib inline

# %% [markdown]
# ## Proakis 5.3a:

# %%
numH = [1, 0]
denH = [1, -0.5]
#################

# compute the impulse response
systemH = signal.dlti(numH, denH)

# %%
w = np.linspace(0,4*np.pi,10000)
w, H = signal.dfreqresp(systemH, w)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 5.3b

# %%
# omega = 3*np.pi/10

# numX = [0, -np.cos(omega), 1]
# denX = [1, -2*np.cos(omega), 1]
# #################

# # compute the impulse response
# systemX = signal.dlti(numX, denX)

w = np.linspace(0,4*np.pi,10000)


plt.figure(figsize = (15,5))
plt.plot(w, H.real);

plt.figure(figsize = (15,5))
plt.plot(w, H.imag);

# %% [markdown]
# ## Proakis 5.4b

# %%
numX = [0.5, -1]
denX = [1, 0]
#################

# compute the impulse response
systemX = signal.dlti(numX, denX)

w = np.linspace(0,np.pi,10000)
w, H = signal.dfreqresp(systemX, w)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 5.4c

# %%
# numX = [0, -1]
# denX = [1, 0]
# #################

# # compute the impulse response
# systemX = signal.dlti(numX, denX)
j = np.complex(0,1)

w = np.linspace(0,np.pi,10000)
# w, H = signal.dfreqresp(systemX, w)
H = np.sin(w)*np.exp(j*np.pi/2)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 5.4i

# %%
w = np.linspace(0,np.pi,10000)
# w, H = signal.dfreqresp(systemX, w
H = 2*np.exp(-j*w) - np.exp(-j*2*w)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %%
w = np.linspace(0,np.pi,10000)
# w, H = signal.dfreqresp(systemX, w)
H = np.cos(w)*np.cos(w/2)*np.exp(-j*3*w/2)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %%
w = np.linspace(0,np.pi,10000)
# w, H = signal.dfreqresp(systemX, w)
H = np.cos(w/2)*np.cos(w/2)*np.cos(w/2)*np.exp(-j*3*w/2)

plt.figure(figsize = (15,5))
plt.plot(w, np.abs(H));

plt.figure(figsize = (15,5))
plt.plot(w, np.angle(H));

# %% [markdown]
# ## Proakis 7.17

# %%
def DFT_matrix(N):
    i, j = np.meshgrid(np.arange(N), np.arange(N))
    omega = np.exp( - 2 * pi * 1J / N )
    W = np.power( omega, i * j ) / sqrt(N)
    return W

# %%
x_n = [1,1,1,1,1,1,0,0]
N = 8

# X_k = np.fft.fft(np.eye(N))
X_k = np.fft.fft(x_n, n=N)

k = np.linspace(0,N,N)
                 
print(k)

plt.figure(figsize = (15,5))
plt.stem(k, np.abs(X_k));

plt.figure(figsize = (15,5))
plt.stem(k, np.angle(X_k));
# Out:
# [0.         1.14285714 2.28571429 3.42857143 4.57142857 5.71428571
#  6.85714286 8.        ]
# /home/sweet/2-coursework/ecec434/labs/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if sys.path[0] == '':
# /home/sweet/2-coursework/ecec434/labs/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
